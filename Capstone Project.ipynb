# %% [markdown]
# This notebook will only be used for the capstone project

# %% [markdown]
# # First Part: Neighborhood

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
# !pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.11.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Libraries imported.

# %% [markdown]
# ## Import Data

# %%
# import packages for web scrapping: beautifulsoup & requests
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen
url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(url,'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))
data = pd.read_json(df[0].to_json(orient='records'))
data = data.rename(columns={'Neighbourhood': 'Neighborhood'})
data.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# ## Clean Data

# %%
data = data[data["Borough"] != "Not assigned"]
data.loc[(data.Neighborhood == "Not assigned"),'Neighborhood']= data.Borough
data.shape
# Out:
# (103, 3)

# %% [markdown]
# # Second Part: Merge Coordinates and Neighborhood

# %%
coord_url = "http://cocl.us/Geospatial_data"
coord_df = pd.read_csv(coord_url)
coord_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df = pd.merge(data,coord_df, on="Postal Code")
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# # Third Part: Explore and Cluster

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_871d7678e0f6452fa5ba230ec1ea6cc0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_871d7678e0f6452fa5ba230ec1ea6cc0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_871d7678e0f6452fa5ba230ec1ea6cc0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_871d7678e0f6452fa5ba230ec1ea6cc0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
CLIENT_ID = 'SECRET' # your Foursquare ID
CLIENT_SECRET = 'SECRET' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SECRET
# CLIENT_SECRET:SECRET

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)          
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)           
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (2130, 7)
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Parkwoods              43.753259              -79.329656
# 1         Parkwoods              43.753259              -79.329656
# 2  Victoria Village              43.725882              -79.315572
# 3  Victoria Village              43.725882              -79.315572
# 4  Victoria Village              43.725882              -79.315572
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0         Brookbanks Park       43.751976       -79.332140
# 1           Variety Store       43.751974       -79.333114
# 2  Victoria Village Arena       43.723481       -79.315635
# 3               Portugril       43.725819       -79.312785
# 4             Tim Hortons       43.725517       -79.313103
#
#           Venue Category
# 0                   Park
# 1      Food & Drink Shop
# 2           Hockey Arena
# 3  Portuguese Restaurant
# 4            Coffee Shop

# %%
toronto_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 271 uniques categories.

# %% [markdown]
# ## Analyze Neigborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                        Agincourt        Breakfast Spot
# 1                           Alderwood, Long Branch           Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North                  Bank
# 3                                  Bayview Village                  Café
# 4                Bedford Park, Lawrence Manor East           Coffee Shop
#
#        2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0  Latin American Restaurant                Lounge          Skating Rink
# 1                        Gym           Coffee Shop        Sandwich Place
# 2                Coffee Shop        Sandwich Place           Supermarket
# 3                       Bank    Chinese Restaurant   Japanese Restaurant
# 4                Pizza Place        Sandwich Place    Italian Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Donut Shop                 Diner        Discount Store
# 1                   Pub        Discount Store      Department Store
# 2        Ice Cream Shop      Sushi Restaurant            Restaurant
# 3         Women's Store          Dessert Shop                 Diner
# 4       Thai Restaurant     Indian Restaurant               Butcher
#
#        8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0        Distribution Center               Dog Run       Doner Restaurant
# 1               Dessert Shop    Dim Sum Restaurant                  Diner
# 2  Middle Eastern Restaurant         Shopping Mall          Deli / Bodega
# 3             Discount Store   Distribution Center                Dog Run
# 4                       Café      Sushi Restaurant                    Pub

# %% [markdown]
# ## Clustering

# %%
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]


# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df

# merge toronto_grouped with df to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged # check the last columns!
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# 26          M1H       Scarborough
# 27          M2H        North York
# 28          M3H        North York
# 29          M4H         East York
# 30          M5H  Downtown Toronto
# 31          M6H      West Toronto
# 32          M1J       Scarborough
# 33          M2J        North York
# 34          M3J        North York
# 35          M4J         East York
# 36          M5J  Downtown Toronto
# 37          M6J      West Toronto
# 38          M1K       Scarborough
# 39          M2K        North York
# 40          M3K        North York
# 41          M4K      East Toronto
# 42          M5K  Downtown Toronto
# 43          M6K      West Toronto
# 44          M1L       Scarborough
# 45          M2L        North York
# 46          M3L        North York
# 47          M4L      East Toronto
# 48          M5L  Downtown Toronto
# 49          M6L        North York
# 50          M9L        North York
# 51          M1M       Scarborough
# 52          M2M        North York
# 53          M3M        North York
# 54          M4M      East Toronto
# 55          M5M        North York
# 56          M6M              York
# 57          M9M        North York
# 58          M1N       Scarborough
# 59          M2N        North York
# 60          M3N        North York
# 61          M4N   Central Toronto
# 62          M5N   Central Toronto
# 63          M6N              York
# 64          M9N              York
# 65          M1P       Scarborough
# 66          M2P        North York
# 67          M4P   Central Toronto
# 68          M5P   Central Toronto
# 69          M6P      West Toronto
# 70          M9P         Etobicoke
# 71          M1R       Scarborough
# 72          M2R        North York
# 73          M4R   Central Toronto
# 74          M5R   Central Toronto
# 75          M6R      West Toronto
# 76          M7R       Mississauga
# 77          M9R         Etobicoke
# 78          M1S       Scarborough
# 79          M4S   Central Toronto
# 80          M5S  Downtown Toronto
# 81          M6S      West Toronto
# 82          M1T       Scarborough
# 83          M4T   Central Toronto
# 84          M5T  Downtown Toronto
# 85          M1V       Scarborough
# 86          M4V   Central Toronto
# 87          M5V  Downtown Toronto
# 88          M8V         Etobicoke
# 89          M9V         Etobicoke
# 90          M1W       Scarborough
# 91          M4W  Downtown Toronto
# 92          M5W  Downtown Toronto
# 93          M8W         Etobicoke
# 94          M9W         Etobicoke
# 95          M1X       Scarborough
# 96          M4X  Downtown Toronto
# 97          M5X  Downtown Toronto
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude  \
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 5              Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 6                                       Malvern, Rouge  43.806686 -79.194353
# 7                                            Don Mills  43.745906 -79.352188
# 8                      Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 9                             Garden District, Ryerson  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 12              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 13                                           Don Mills  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# 30                            Richmond, Adelaide, King  43.650571 -79.384568
# 31                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 32                                 Scarborough Village  43.744734 -79.239476
# 33                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 34                     Northwood Park, York University  43.767980 -79.487262
# 35       East Toronto, Broadview North (Old East York)  43.685347 -79.338106
# 36   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 38         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 39                                     Bayview Village  43.786947 -79.385975
# 40                                           Downsview  43.737473 -79.464763
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 43        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 44                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 45                            York Mills, Silver Hills  43.757490 -79.374714
# 46                                           Downsview  43.739015 -79.506944
# 47                      India Bazaar, The Beaches West  43.668999 -79.315572
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 49            North Park, Maple Leaf Park, Upwood Park  43.713756 -79.490074
# 50                                       Humber Summit  43.756303 -79.565963
# 51     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 52                             Willowdale, Newtonbrook  43.789053 -79.408493
# 53                                           Downsview  43.728496 -79.495697
# 54                                     Studio District  43.659526 -79.340923
# 55                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 56    Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 57                                    Humberlea, Emery  43.724766 -79.532242
# 58                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 59                         Willowdale, Willowdale East  43.770120 -79.408493
# 60                                           Downsview  43.761631 -79.520999
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 63                       Runnymede, The Junction North  43.673185 -79.487262
# 64                                              Weston  43.706876 -79.518188
# 65   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 66                                     York Mills West  43.752758 -79.400049
# 67                                    Davisville North  43.712751 -79.390197
# 68     Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 69                       High Park, The Junction South  43.661608 -79.464763
# 70                                           Westmount  43.696319 -79.532242
# 71                                   Wexford, Maryvale  43.750072 -79.295849
# 72                         Willowdale, Willowdale West  43.782736 -79.442259
# 73                   North Toronto West, Lawrence Park  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      University of Toronto, Harbord  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 85   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 86   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 87   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89   South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 90                       Steeles West, L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                                      Stn A PO Boxes  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                 Northwest, West Humber - Clairville  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         St. James Town, Cabbagetown  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
#      Cluster Labels       1st Most Common Venue  \
# 0               0.0                        Park
# 1               4.0       Portuguese Restaurant
# 2               1.0                 Coffee Shop
# 3               1.0              Clothing Store
# 4               1.0                 Coffee Shop
# 5               NaN                         NaN
# 6               3.0        Fast Food Restaurant
# 7               1.0                         Gym
# 8               1.0                 Pizza Place
# 9               1.0                 Coffee Shop
# 10              1.0                        Park
# 11              NaN                         NaN
# 12              1.0  Construction & Landscaping
# 13              1.0                         Gym
# 14              1.0                        Park
# 15              1.0                 Coffee Shop
# 16              1.0                       Field
# 17              1.0                   Pet Store
# 18              1.0              Medical Center
# 19              1.0                       Trail
# 20              1.0                 Coffee Shop
# 21              0.0                        Park
# 22              4.0                 Coffee Shop
# 23              1.0                 Coffee Shop
# 24              1.0                 Coffee Shop
# 25              1.0               Grocery Store
# 26              1.0         Fried Chicken Joint
# 27              3.0    Mediterranean Restaurant
# 28              1.0                        Bank
# 29              1.0           Indian Restaurant
# 30              1.0                 Coffee Shop
# 31              1.0                      Bakery
# 32              1.0           Convenience Store
# 33              1.0              Clothing Store
# 34              1.0                         Bar
# 35              0.0                        Park
# 36              1.0                 Coffee Shop
# 37              1.0                         Bar
# 38              1.0            Department Store
# 39              1.0                        Café
# 40              1.0               Grocery Store
# 41              1.0            Greek Restaurant
# 42              1.0                 Coffee Shop
# 43              1.0                        Café
# 44              1.0                      Bakery
# 45              NaN                         NaN
# 46              1.0               Grocery Store
# 47              1.0        Fast Food Restaurant
# 48              1.0                 Coffee Shop
# 49              1.0                        Park
# 50              3.0                         Gym
# 51              1.0                       Motel
# 52              0.0                        Park
# 53              1.0               Grocery Store
# 54              1.0                 Coffee Shop
# 55              1.0                 Coffee Shop
# 56              4.0                 Coffee Shop
# 57              2.0              Baseball Field
# 58              1.0             College Stadium
# 59              1.0            Ramen Restaurant
# 60              1.0               Grocery Store
# 61              1.0            Business Service
# 62              1.0                 Music Venue
# 63              4.0           Convenience Store
# 64              0.0                        Park
# 65              3.0           Indian Restaurant
# 66              0.0           Convenience Store
# 67              1.0                Dance Studio
# 68              1.0                        Park
# 69              1.0          Mexican Restaurant
# 70              4.0                 Pizza Place
# 71              1.0   Middle Eastern Restaurant
# 72              4.0               Grocery Store
# 73              1.0                 Coffee Shop
# 74              1.0                        Café
# 75              1.0                   Gift Shop
# 76              1.0                 Coffee Shop
# 77              1.0                        Park
# 78              1.0              Breakfast Spot
# 79              1.0              Sandwich Place
# 80              1.0                        Café
# 81              1.0                        Café
# 82              3.0                 Pizza Place
# 83              1.0                  Restaurant
# 84              1.0                        Café
# 85              0.0                        Park
# 86              1.0                 Coffee Shop
# 87              1.0              Airport Lounge
# 88              1.0                        Café
# 89              3.0               Grocery Store
# 90              3.0        Fast Food Restaurant
# 91              0.0                        Park
# 92              1.0                 Coffee Shop
# 93              4.0                 Pizza Place
# 94              1.0         Rental Car Location
# 95              NaN                         NaN
# 96              1.0                 Coffee Shop
# 97              1.0                 Coffee Shop
# 98              0.0                        Park
# 99              1.0                 Coffee Shop
# 100             1.0          Light Rail Station
# 101             2.0              Baseball Field
# 102             1.0                         Gym
#
#              2nd Most Common Venue          3rd Most Common Venue  \
# 0                Food & Drink Shop                  Women's Store
# 1                      Coffee Shop                   Intersection
# 2                             Park                         Bakery
# 3           Furniture / Home Store              Accessories Store
# 4                 Sushi Restaurant                            Gym
# 5                              NaN                            NaN
# 6                 Department Store                    Event Space
# 7                       Beer Store            Japanese Restaurant
# 8                        Pet Store                    Flea Market
# 9                   Clothing Store                           Café
# 10             Japanese Restaurant                    Pizza Place
# 11                             NaN                            NaN
# 12                             Bar                  Women's Store
# 13                      Beer Store            Japanese Restaurant
# 14                     Curling Ice                     Beer Store
# 15                            Café            American Restaurant
# 16                      Playground                   Hockey Arena
# 17                    Liquor Store                     Beer Store
# 18               Electronics Store                     Restaurant
# 19                Asian Restaurant                    Coffee Shop
# 20                    Cocktail Bar                     Restaurant
# 21                            Pool                  Women's Store
# 22           Korean BBQ Restaurant                  Women's Store
# 23             Sporting Goods Shop         Furniture / Home Store
# 24              Italian Restaurant                           Café
# 25                            Café                           Park
# 26                     Gas Station               Hakka Restaurant
# 27                     Golf Course           Fast Food Restaurant
# 28                     Coffee Shop                 Sandwich Place
# 29                             Gym                  Grocery Store
# 30                            Café                          Hotel
# 31                        Pharmacy                    Coffee Shop
# 32                      Playground                  Women's Store
# 33                     Coffee Shop           Fast Food Restaurant
# 34          Furniture / Home Store                    Coffee Shop
# 35               Convenience Store                   Intersection
# 36                        Aquarium                          Hotel
# 37                     Coffee Shop  Vegetarian / Vegan Restaurant
# 38              Chinese Restaurant                    Bus Station
# 39                            Bank             Chinese Restaurant
# 40                            Park                     Food Truck
# 41                     Coffee Shop             Italian Restaurant
# 42                           Hotel                           Café
# 43                     Coffee Shop                 Breakfast Spot
# 44                    Soccer Field                   Intersection
# 45                             NaN                            NaN
# 46                            Park                     Food Truck
# 47                  Sandwich Place                            Gym
# 48                      Restaurant                           Café
# 49                          Bakery     Construction & Landscaping
# 50                     Pizza Place         Furniture / Home Store
# 51             American Restaurant                  Women's Store
# 52                   Women's Store               Doner Restaurant
# 53                            Park                     Food Truck
# 54                          Bakery                      Gastropub
# 55                     Pizza Place                 Sandwich Place
# 56                  Sandwich Place                 Discount Store
# 57                    Food Service                  Women's Store
# 58                            Café                   Skating Rink
# 59                     Coffee Shop                    Pizza Place
# 60                            Park                     Food Truck
# 61                        Bus Line                    Swim School
# 62                            Pool                         Garden
# 63                     Pizza Place                  Women's Store
# 64               Convenience Store                  Jewelry Store
# 65                       Pet Store          Vietnamese Restaurant
# 66                            Park                  Women's Store
# 67                            Park           Gym / Fitness Center
# 68                        Bus Line               Sushi Restaurant
# 69                 Thai Restaurant                           Café
# 70              Chinese Restaurant      Middle Eastern Restaurant
# 71           Vietnamese Restaurant                  Shopping Mall
# 72                        Pharmacy                    Pizza Place
# 73                  Clothing Store                     Bagel Shop
# 74                  Sandwich Place                    Coffee Shop
# 75                  Breakfast Spot                      Bookstore
# 76                           Hotel            American Restaurant
# 77                  Sandwich Place                       Bus Line
# 78       Latin American Restaurant                         Lounge
# 79                     Pizza Place                   Dessert Shop
# 80                          Bakery             Italian Restaurant
# 81                     Coffee Shop               Sushi Restaurant
# 82                            Bank           Fast Food Restaurant
# 83                           Trail                   Tennis Court
# 84   Vegetarian / Vegan Restaurant             Mexican Restaurant
# 85                      Playground                   Intersection
# 86             American Restaurant                    Pizza Place
# 87                Airport Terminal                Airport Service
# 88             American Restaurant                   Liquor Store
# 89                  Sandwich Place                     Beer Store
# 90                   Grocery Store                    Coffee Shop
# 91                           Trail                     Playground
# 92              Seafood Restaurant            Japanese Restaurant
# 93                             Gym                    Coffee Shop
# 94                       Drugstore                  Garden Center
# 95                             NaN                            NaN
# 96              Italian Restaurant                     Restaurant
# 97                            Café                          Hotel
# 98                           River                           Pool
# 99                Sushi Restaurant            Japanese Restaurant
# 100                    Yoga Studio                         Garden
# 101                     Donut Shop             Dim Sum Restaurant
# 102                  Tanning Salon              Convenience Store
#
#          4th Most Common Venue    5th Most Common Venue  \
# 0             Doner Restaurant       Dim Sum Restaurant
# 1                 Hockey Arena        French Restaurant
# 2                         Café                      Pub
# 3                  Coffee Shop              Event Space
# 4               Discount Store           Sandwich Place
# 5                          NaN                      NaN
# 6         Ethiopian Restaurant              Escape Room
# 7                   Restaurant              Coffee Shop
# 8               Breakfast Spot     Gym / Fitness Center
# 9               Cosmetics Shop                    Hotel
# 10                      Bakery                      Pub
# 11                         NaN                      NaN
# 12                  Donut Shop                    Diner
# 13                  Restaurant              Coffee Shop
# 14                         Spa             Intersection
# 15                Cocktail Bar      Moroccan Restaurant
# 16                       Trail            Women's Store
# 17                    Pharmacy              Pizza Place
# 18              Breakfast Spot      Rental Car Location
# 19           Health Food Store                      Pub
# 20                 Cheese Shop                   Bakery
# 21                 Golf Course     Ethiopian Restaurant
# 22            Doner Restaurant       Dim Sum Restaurant
# 23                        Bank             Burger Joint
# 24              Sandwich Place              Salad Place
# 25                 Candy Store       Italian Restaurant
# 26                      Bakery       Athletics & Sports
# 27                        Pool                  Dog Run
# 28                 Supermarket           Ice Cream Shop
# 29                  Restaurant              Pizza Place
# 30                  Restaurant                      Gym
# 31                 Pizza Place                  Brewery
# 32                Dessert Shop       Dim Sum Restaurant
# 33                  Restaurant               Shoe Store
# 34              Massage Studio     Caribbean Restaurant
# 35            Doner Restaurant       Dim Sum Restaurant
# 36                        Café                  Brewery
# 37                  Restaurant                     Café
# 38                 Coffee Shop           Discount Store
# 39         Japanese Restaurant            Women's Store
# 40                     Airport             Liquor Store
# 41              Ice Cream Shop                Bookstore
# 42                 Salad Place               Restaurant
# 43                         Gym                  Stadium
# 44                    Bus Line           Ice Cream Shop
# 45                         NaN                      NaN
# 46                     Airport             Liquor Store
# 47            Sushi Restaurant           Ice Cream Shop
# 48                       Hotel                      Gym
# 49            Basketball Court               Donut Shop
# 50                Home Service                  Dog Run
# 51               Deli / Bodega             Dessert Shop
# 52                Dessert Shop       Dim Sum Restaurant
# 53                     Airport             Liquor Store
# 54                     Brewery                     Café
# 55          Italian Restaurant          Thai Restaurant
# 56          Turkish Restaurant            Women's Store
# 57                       Diner           Discount Store
# 58       General Entertainment            Women's Store
# 59                        Café               Restaurant
# 60                     Airport             Liquor Store
# 61                        Park  Comfort Food Restaurant
# 62              Ice Cream Shop            Women's Store
# 63                Dessert Shop       Dim Sum Restaurant
# 64                  Donut Shop       Dim Sum Restaurant
# 65          Chinese Restaurant      Distribution Center
# 66          Dim Sum Restaurant                    Diner
# 67                 Pizza Place                    Hotel
# 68               Jewelry Store                    Trail
# 69        Fast Food Restaurant           Discount Store
# 70              Sandwich Place              Coffee Shop
# 71                      Bakery              Auto Garage
# 72                 Coffee Shop           Discount Store
# 73        Gym / Fitness Center     Fast Food Restaurant
# 74   Middle Eastern Restaurant        Indian Restaurant
# 75                     Dog Run               Restaurant
# 76    Mediterranean Restaurant            Burrito Place
# 77           Mobile Phone Shop                Drugstore
# 78                Skating Rink               Donut Shop
# 79                         Gym              Coffee Shop
# 80         Japanese Restaurant                      Bar
# 81                         Pub       Italian Restaurant
# 82                Noodle House      Fried Chicken Joint
# 83                        Park          College Stadium
# 84                 Coffee Shop    Vietnamese Restaurant
# 85                     Dog Run             Dessert Shop
# 86                 Supermarket               Restaurant
# 87               Boat or Ferry                    Plane
# 88        Fast Food Restaurant       Seafood Restaurant
# 89        Fast Food Restaurant      Fried Chicken Joint
# 90                        Bank           Sandwich Place
# 91            Department Store             Dessert Shop
# 92          Italian Restaurant                 Beer Bar
# 93              Sandwich Place                      Pub
# 94               Women's Store           Discount Store
# 95                         NaN                      NaN
# 96                         Pub                     Café
# 97                         Gym               Restaurant
# 98              Discount Store            Deli / Bodega
# 99                  Restaurant                  Gay Bar
# 100                 Smoke Shop                  Brewery
# 101                      Diner           Discount Store
# 102             Discount Store            Burrito Place
#
#          6th Most Common Venue        7th Most Common Venue  \
# 0                        Diner               Discount Store
# 1                  Pizza Place                    Drugstore
# 2               Breakfast Spot                      Theater
# 3          Arts & Crafts Store                     Boutique
# 4                         Park           Mexican Restaurant
# 5                          NaN                          NaN
# 6            Electronics Store  Eastern European Restaurant
# 7               Clothing Store           Italian Restaurant
# 8                         Bank                     Pharmacy
# 9    Middle Eastern Restaurant              Bubble Tea Shop
# 10                Dessert Shop           Dim Sum Restaurant
# 11                         NaN                          NaN
# 12              Discount Store          Distribution Center
# 13              Clothing Store           Italian Restaurant
# 14                    Bus Stop           Athletics & Sports
# 15                 Cheese Shop                         Park
# 16                     Dog Run                 Dessert Shop
# 17                 Coffee Shop                         Café
# 18                Intersection                         Bank
# 19                     Dog Run                 Dessert Shop
# 20                    Beer Bar           Seafood Restaurant
# 21           Electronics Store  Eastern European Restaurant
# 22                       Diner               Discount Store
# 23            Sushi Restaurant                   Bagel Shop
# 24             Thai Restaurant                 Burger Joint
# 25                        Bank                   Baby Store
# 26                        Bank         Caribbean Restaurant
# 27               Women's Store           Dim Sum Restaurant
# 28            Sushi Restaurant                   Restaurant
# 29                    Pharmacy                         Park
# 30             Thai Restaurant                Deli / Bodega
# 31                         Bar                         Bank
# 32                       Diner               Discount Store
# 33                        Bank                       Bakery
# 34               Metro Station                Women's Store
# 35                       Diner               Discount Store
# 36                  Restaurant               Scenic Lookout
# 37            Asian Restaurant                  Men's Store
# 38           Convenience Store                   Hobby Shop
# 39                Dessert Shop                        Diner
# 40               Shopping Mall                         Bank
# 41      Furniture / Home Store                 Liquor Store
# 42          Italian Restaurant           Seafood Restaurant
# 43               Burrito Place                   Restaurant
# 44                        Park            Electronics Store
# 45                         NaN                          NaN
# 46               Shopping Mall                         Bank
# 47           Fish & Chips Shop           Italian Restaurant
# 48         American Restaurant           Seafood Restaurant
# 49                       Diner               Discount Store
# 50                Dessert Shop           Dim Sum Restaurant
# 51          Dim Sum Restaurant                        Diner
# 52                       Diner               Discount Store
# 53               Shopping Mall                         Bank
# 54         American Restaurant                  Yoga Studio
# 55           Indian Restaurant                      Butcher
# 56            Doner Restaurant           Dim Sum Restaurant
# 57         Distribution Center                      Dog Run
# 58                     Dog Run           Dim Sum Restaurant
# 59            Sushi Restaurant               Sandwich Place
# 60               Shopping Mall                         Bank
# 61        Colombian Restaurant         Ethiopian Restaurant
# 62            Department Store                 Dessert Shop
# 63                       Diner               Discount Store
# 64                       Diner               Discount Store
# 65                Dessert Shop           Dim Sum Restaurant
# 66              Discount Store          Distribution Center
# 67              Breakfast Spot            Food & Drink Shop
# 68               Women's Store                      Dog Run
# 69                         Bar                       Bakery
# 70                Intersection               Discount Store
# 71              Sandwich Place          Distribution Center
# 72               Women's Store                      Dog Run
# 73                       Diner           Mexican Restaurant
# 74                   BBQ Joint                          Pub
# 75          Italian Restaurant                          Bar
# 76              Sandwich Place                 Intersection
# 77                  Donut Shop             Doner Restaurant
# 78                       Diner               Discount Store
# 79                        Park                         Café
# 80                   Bookstore                          Pub
# 81                         Gym                 Gourmet Shop
# 82          Italian Restaurant            Convenience Store
# 83        Colombian Restaurant                  Escape Room
# 84     Comfort Food Restaurant                          Bar
# 85          Dim Sum Restaurant                        Diner
# 86                         Pub                         Bank
# 87                 Coffee Shop              Harbor / Marina
# 88          Mexican Restaurant                       Bakery
# 89                    Pharmacy                  Pizza Place
# 90      Furniture / Home Store           Chinese Restaurant
# 91          Dim Sum Restaurant                        Diner
# 92                  Restaurant                 Cocktail Bar
# 93              Discount Store             Department Store
# 94            Department Store                 Dessert Shop
# 95                         NaN                          NaN
# 96                      Bakery                         Park
# 97         Japanese Restaurant                Deli / Bodega
# 98            Department Store                 Dessert Shop
# 99                 Yoga Studio                         Café
# 100             Farmers Market         Fast Food Restaurant
# 101        Distribution Center                      Dog Run
# 102               Burger Joint               Sandwich Place
#
#            8th Most Common Venue        9th Most Common Venue  \
# 0            Distribution Center                      Dog Run
# 1                     Donut Shop             Doner Restaurant
# 2                            Spa                   Shoe Store
# 3             Miscellaneous Shop        Vietnamese Restaurant
# 4            Japanese Restaurant           Italian Restaurant
# 5                            NaN                          NaN
# 6                      Drugstore                   Donut Shop
# 7             Dim Sum Restaurant                  Supermarket
# 8                   Intersection           Athletics & Sports
# 9            Japanese Restaurant           Italian Restaurant
# 10                         Diner               Discount Store
# 11                           NaN                          NaN
# 12                       Dog Run             Doner Restaurant
# 13            Dim Sum Restaurant                  Supermarket
# 14                  Skating Rink            Convenience Store
# 15                Clothing Store                          Gym
# 16            Dim Sum Restaurant                        Diner
# 17                Shopping Plaza            Convenience Store
# 18           Distribution Center                        Diner
# 19            Dim Sum Restaurant                        Diner
# 20                Farmers Market                         Park
# 21                     Drugstore                   Donut Shop
# 22           Distribution Center                      Dog Run
# 23                   Supermarket            Fish & Chips Shop
# 24               Bubble Tea Shop                    Juice Bar
# 25                    Restaurant                  Coffee Shop
# 26               Thai Restaurant           Dim Sum Restaurant
# 27                         Diner               Discount Store
# 28     Middle Eastern Restaurant                Shopping Mall
# 29                  Intersection                  Gas Station
# 30                        Lounge             Sushi Restaurant
# 31                   Supermarket                         Café
# 32           Distribution Center                      Dog Run
# 33           Japanese Restaurant                    Juice Bar
# 34                         Diner               Discount Store
# 35           Distribution Center                      Dog Run
# 36           Fried Chicken Joint           Italian Restaurant
# 37         Vietnamese Restaurant               Ice Cream Shop
# 38            Dim Sum Restaurant                        Diner
# 39                Discount Store          Distribution Center
# 40            Athletics & Sports               Baseball Field
# 41             Indian Restaurant                          Spa
# 42           American Restaurant          Japanese Restaurant
# 43                  Climbing Gym                    Pet Store
# 44   Eastern European Restaurant                    Drugstore
# 45                           NaN                          NaN
# 46            Athletics & Sports               Baseball Field
# 47                  Liquor Store                Movie Theater
# 48           Japanese Restaurant           Italian Restaurant
# 49           Distribution Center                      Dog Run
# 50                         Diner               Discount Store
# 51                Discount Store          Distribution Center
# 52           Distribution Center                      Dog Run
# 53            Athletics & Sports               Baseball Field
# 54             Convenience Store                    Bookstore
# 55                          Café             Sushi Restaurant
# 56                         Diner          Distribution Center
# 57              Doner Restaurant                   Donut Shop
# 58                         Diner               Discount Store
# 59                 Shopping Mall            Electronics Store
# 60            Athletics & Sports               Baseball Field
# 61                   Escape Room            Electronics Store
# 62            Dim Sum Restaurant                        Diner
# 63           Distribution Center                      Dog Run
# 64           Distribution Center                      Dog Run
# 65                         Diner               Discount Store
# 66                       Dog Run             Doner Restaurant
# 67              Department Store               Sandwich Place
# 68            Dim Sum Restaurant                        Diner
# 69                   Flea Market           Italian Restaurant
# 70                 Women's Store           Dim Sum Restaurant
# 71                  Dessert Shop           Dim Sum Restaurant
# 72                  Dessert Shop           Dim Sum Restaurant
# 73                Cosmetics Shop                         Park
# 74                History Museum                 Liquor Store
# 75              Cuban Restaurant                Movie Theater
# 76           Fried Chicken Joint                  Gas Station
# 77                       Dog Run         Ethiopian Restaurant
# 78           Distribution Center                      Dog Run
# 79              Sushi Restaurant           Italian Restaurant
# 80                          Bank                     Beer Bar
# 81                Sandwich Place                  Pizza Place
# 82                   Gas Station           Chinese Restaurant
# 83             Electronics Store  Eastern European Restaurant
# 84           Arts & Crafts Store                 Dessert Shop
# 85                Discount Store          Distribution Center
# 86           Fried Chicken Joint             Sushi Restaurant
# 87              Sculpture Garden                 Airport Gate
# 88                    Restaurant          Fried Chicken Joint
# 89          Colombian Restaurant                 Dessert Shop
# 90             Indian Restaurant                  Pizza Place
# 91                Discount Store          Distribution Center
# 92                          Café                          Gym
# 93                  Dessert Shop           Dim Sum Restaurant
# 94            Dim Sum Restaurant                        Diner
# 95                           NaN                          NaN
# 96                   Pizza Place            Convenience Store
# 97                   Salad Place                   Steakhouse
# 98            Dim Sum Restaurant                        Diner
# 99          Fast Food Restaurant                          Pub
# 100                Burrito Place                   Restaurant
# 101             Doner Restaurant                Women's Store
# 102                   Kids Store                  Flower Shop
#
#           10th Most Common Venue
# 0                     Donut Shop
# 1                        Dog Run
# 2                        Brewery
# 3    Eastern European Restaurant
# 4                     Hobby Shop
# 5                            NaN
# 6               Doner Restaurant
# 7           Caribbean Restaurant
# 8                      Gastropub
# 9                        Theater
# 10           Distribution Center
# 11                           NaN
# 12                     Drugstore
# 13          Caribbean Restaurant
# 14                Discount Store
# 15                    Restaurant
# 16                Discount Store
# 17           Distribution Center
# 18                Discount Store
# 19                Discount Store
# 20                     Irish Pub
# 21              Doner Restaurant
# 22                     Drugstore
# 23                    Sports Bar
# 24             Indian Restaurant
# 25                     Nightclub
# 26                         Diner
# 27           Distribution Center
# 28                 Deli / Bodega
# 29                   Supermarket
# 30                        Bakery
# 31     Middle Eastern Restaurant
# 32              Doner Restaurant
# 33                 Women's Store
# 34           Distribution Center
# 35                 Women's Store
# 36              Baseball Stadium
# 37                  Cocktail Bar
# 38           Distribution Center
# 39                       Dog Run
# 40                Discount Store
# 41           Japanese Restaurant
# 42                Breakfast Spot
# 43                        Bakery
# 44                    Donut Shop
# 45                           NaN
# 46                Discount Store
# 47                     Pet Store
# 48                 Deli / Bodega
# 49              Doner Restaurant
# 50           Distribution Center
# 51                       Dog Run
# 52                    Donut Shop
# 53                Discount Store
# 54            Seafood Restaurant
# 55                           Pub
# 56                       Dog Run
# 57                  Dessert Shop
# 58           Distribution Center
# 59                     Juice Bar
# 60                Discount Store
# 61   Eastern European Restaurant
# 62                Discount Store
# 63              Doner Restaurant
# 64              Doner Restaurant
# 65                       Dog Run
# 66                    Donut Shop
# 67                         Diner
# 68                Discount Store
# 69                     Speakeasy
# 70                         Diner
# 71                         Diner
# 72                         Diner
# 73                     Pet Store
# 74                   Pizza Place
# 75                  Dessert Shop
# 76                           Gym
# 77                Discount Store
# 78              Doner Restaurant
# 79           Indie Movie Theater
# 80                    Beer Store
# 81     Latin American Restaurant
# 82               Thai Restaurant
# 83                     Drugstore
# 84          Caribbean Restaurant
# 85              Doner Restaurant
# 86                    Bagel Shop
# 87                       Airport
# 88                           Gym
# 89             Electronics Store
# 90                      Pharmacy
# 91                       Dog Run
# 92                   Cheese Shop
# 93                         Diner
# 94           Distribution Center
# 95                           NaN
# 96                    Playground
# 97              Asian Restaurant
# 98           Distribution Center
# 99                         Hotel
# 100                Auto Workshop
# 101               Farmers Market
# 102                       Bakery

# %% [markdown]
# ### Here we define the cluster by 5 colors and the color black for the NaN in the Cluster Labels

# %%
# create map
colors = {0.0: "green",1.0:"red", 2.0:"blue",3.0:"orange",4.0:"green","NaN":"black"}
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
review = [0.0,1.0,2.0,3.0,4.0]
# set color scheme for the clusters
#x = np.arange(kclusters)
#ys = [i + x + (i*x)**2 for i in range(kclusters)]
#colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
#rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    if cluster not in [0.0,1.0,2.0,3.0,4.0]:
        cluster = "NaN"
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color= colors[cluster],
        fill=True,
        #fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_09e7405676654225af7fe6d8ab2adc46%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_09e7405676654225af7fe6d8ab2adc46%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_09e7405676654225af7fe6d8ab2adc46%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_09e7405676654225af7fe6d8ab2adc46%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
